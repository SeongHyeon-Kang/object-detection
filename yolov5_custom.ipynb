# %% [markdown]
# <a href="https://colab.research.google.com/github/SeongHyeon-Kang/object-detection/blob/main/yolov5_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# %pip install -qr requirements.txt 

import torch
from IPython.display import Image, clear_output  

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla T4)

# %%
# !unzip -q /content/drive/MyDrive/train_data.zip -d ../

# %%
# Train YOLOv5
# !python train.py --img 640 --batch 16 --epochs 150 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-42-g4200674 torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='./data/custom_data.yaml', device='', entity=None, epochs=150, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
Image(filename='runs/train/exp3/test_batch0_pred.jpg', width=1600)  # test batch 0 predictions

# %%
Image(filename='runs/train/exp3/test_batch1_pred.jpg', width=1600)  # test batch 0 predictions

# %%
Image(filename='runs/train/exp3/test_batch2_pred.jpg', width=1600)  # test batch 0 predictions

# %%
# !python detect.py --weights runs/train/exp5/weights/last.pt --img 640 --conf 0.25 --source ../test1.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='../test1.jpg', update=False, view_img=False, weights=['runs/train/exp5/weights/last.pt'])
# YOLOv5 🚀 v5.0-14-g238583b torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7059304 parameters, 0 gradients, 16.3 GFLOPS
# image 1/1 /content/yolov5/../test1.jpg: 640x448 1 beef, Done. (0.011s)
# Results saved to runs/detect/exp5
# Done. (0.044s)

# %%
Image(filename='/content/yolov5/runs/train/exp/F1_curve.png', width=800)  # test batch 0 predictions

# %%
Image(filename='/content/yolov5/runs/train/exp/PR_curve.png', width=800)  # test batch 0 predictions

# %%
Image(filename='/content/yolov5/runs/train/exp/P_curve.png', width=800)  # test batch 0 predictions

# %%
Image(filename='/content/yolov5/runs/train/exp/R_curve.png', width=800)  # test batch 0 predictions

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../beef.mp4

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../chicken.mp4

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../pork.mp4

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data custom_data.yaml --weights yolov5s.pt --nosave --cache
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/ultralytics/yolov5
#    45632b2..de19d39  master     -> origin/master
# github: ⚠️ WARNING: code is out of date by 2 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 v5.0-31-g1b1ab4c torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...
